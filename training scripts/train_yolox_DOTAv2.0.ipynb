# %%
import torch
print(torch.cuda.is_available())      
print(torch.cuda.device_count())

# %% [markdown]
# ### Load dataset
#
# Dataset from: https://captain-whu.github.io/DOTA/dataset.html
# Full list of albumations functions in ultralytics: https://docs.ultralytics.com/reference/data/augment/h=albumentation#ultralyticsdataaugmentBaseTransform
#
# `convert_dota_to_yolo_obb` <br>
# Converts DOTA dataset annotations to YOLO OBB (Oriented Bounding Box) format. The function processes images in the 'train' and 'val' folders of the DOTA dataset. For each image, it reads the associated label from the original labels directory and writes new labels in YOLO OBB format to a new directory.
#
# `split_trainval` <br>
# Restructures dataset directory and applies image augmentation to enrich dataset.
# ```
# data_root/
# ├── images/
# │   ├── train/
# │   └── val/
# └── labels/
#     ├── train_original/
#     └── val_original/
# ```
#
# And the output directory structure is:
#
# ```
# save_dir/
# ├── images/
# │   ├── train/
# │   └── val/
# └── labels/
#     ├── train/
#     └── val/
# ```

# %%
from ultralytics.data.converter import convert_dota_to_yolo_obb
from ultralytics.data.split_dota import split_test, split_trainval

#Run this once to convert labels and save them with images in a new directory
#convert_dota_to_yolo_obb("datasets/DOTAv2.0")

from PIL import Image
Image.MAX_IMAGE_PIXELS = None

# split train and val set, with labels.
split_trainval(
    data_root="datasets/DOTAv2.0/",
    save_dir="datasets/DOTAv2.0/processed/",
    rates=[0.5, 1.0, 1.5],  # Generate different versions or crops of the images
    gap=500, # Split into patches with a specific overlap or gap
)
# # split test set, without labels.
# split_test(
#     data_root="DOTAv1.0/",
#     save_dir="DOTAv1.0-split/",
#     rates=[0.5, 1.0, 1.5],  # multiscale
#     gap=500,
# )

# %% [markdown]
# ### Inspect dataset

# %%
from pathlib import Path

root = Path("datasets/DOTAv2.0")
image_exts = {".jpg", ".jpeg", ".png"}
label_exts = {".txt"}

# Count images in each subdirectory under DOTAv2/images
print("DOTAv2.0")
print("Image counts:")
for subdir in (root / "images").iterdir():
    if subdir.is_dir():
        count = sum(1 for file in subdir.rglob("*") if file.suffix.lower() in image_exts)
        print(f"  {subdir.name}: {count}")

# Count labels in each subdirectory under DOTAv2/labels
print("\nLabel counts:")
for subdir in (root / "labels").iterdir():
    if subdir.is_dir():
        count = sum(1 for file in subdir.rglob("*") if file.suffix.lower() in label_exts)
        print(f"  {subdir.name}: {count}")
        if subdir.name == "val_original":
            print()  # Extra line break after 'val_original'

# Repeat for DOTAv2_processed
root2 = Path("datasets/DOTAv2.0/processed")
print("\nDOTAv2_processed")
print("Image counts:")
for subdir in (root2 / "images").iterdir():
    if subdir.is_dir():
        count = sum(1 for file in subdir.rglob("*") if file.suffix.lower() in image_exts)
        print(f"  {subdir.name}: {count}")

print("\nLabel counts:")
for subdir in (root2 / "labels").iterdir():
    if subdir.is_dir():
        count = sum(1 for file in subdir.rglob("*") if file.suffix.lower() in label_exts)
        print(f"  {subdir.name}: {count}")
        if subdir.name == "val_original":
            print()  # Extra line break after 'val_original'

# %% [markdown]
# ### Load model

# %%
from ultralytics import YOLO

# Load a pretrained model
model = YOLO("models/yolo11x-obb.pt") # n for nano, x for extra-large

# %% [markdown]
# ### Train model
# Includes list of augmentations to apply to each batch before training loop. Doesn't create more images, just augments the existing ones (and labels accordingly) to enrich dataset.

# %%
results = model.train(
    data="datasets/DOTAv2.0/dotav2.yml", # Path to custom dataset YAML
    epochs=100,                          # Total number of training epochs
    imgsz=640,                           # Input image size for training
    patience=15,                         # patience: Number of epochs with no improvement before early stopping
    batch=12,                            # batch: Batch size (use -1 or a fraction for auto GPU memory utilization)
    save=True,                           # save: Save training checkpoints and final model weights
    save_period=-1,                      # save_period: Frequency (in epochs) for saving checkpoints; -1 disables
    cache=False,                         # cache: Enable caching of dataset images (True for RAM, 'disk' for disk caching)
    device='0, 1',                       # device: Specify the computational device (e.g., 0, "cpu", or list of GPUs)
    workers=8,                           # workers: Number of worker threads for data loading
    project="test_yolo",                 # project: Name of the project directory for saving outputs
    name="experiment_1",                 # name: Name of the training run
    exist_ok=False,                      # exist_ok: Allow overwriting an existing project/name directory if True
    pretrained=False,                    # pretrained: Start from a pretrained model or provide a path to one
    optimizer="auto",                    # optimizer: Choice of optimizer (e.g., 'SGD', 'Adam', or 'auto')
    seed=18,                             # seed: Random seed for reproducibility
    single_cls=False,                    # single_cls: Treat all classes as a single class (useful for binary tasks)
    classes=None,                        # classes: List of class IDs to train on; None uses all classes
    rect=False,                          # rect: Enable rectangular training to minimize padding in batches
    multi_scale=True,                    # multi_scale: Enable multi-scale training by varying the imgsz during training
    cos_lr=False,                        # cos_lr: Use a cosine learning rate scheduler
    close_mosaic=10,                     # close_mosaic: Disable mosaic augmentation in the last N epochs
    resume=False,                        # resume: Resume training from the last checkpoint if available
    amp=True,                            # amp: Enable Automatic Mixed Precision training
    #fraction=1.0,                       # fraction: Fraction of the dataset to use for training
    freeze=None,                         # freeze: Freeze the first N layers or specify list of layers to freeze
    lr0=0.01,                            # lr0: Initial learning rate
    lrf=0.001,                           # lrf: Final learning rate as a fraction of lr0 (lr0 * lrf)
    momentum=0.937,                      # momentum: Momentum factor for the optimizer
    weight_decay=0.0005,                 # weight_decay: L2 regularization coefficient to prevent overfitting
    warmup_epochs=3.0,                   # warmup_epochs: Number of epochs for learning rate warmup
    warmup_momentum=0.8,                 # warmup_momentum: Initial momentum value during the warmup phase
    warmup_bias_lr=0.1,                  # warmup_bias_lr: Learning rate for bias parameters during warmup
    box=7.5,                             # box: Weight of the box loss component (bounding box regression)
    cls=0.5,                             # cls: Weight of the classification loss component
    dfl=1.5,                             # dfl: Weight of the distribution focal loss for fine-grained classification
    pose=12.0,                           # pose: Weight of the pose loss for keypoint or pose estimation tasks
    kobj=2.0,                            # kobj: Weight of the keypoint objectness loss in pose estimation models
    nbs=64,                              # nbs: Nominal batch size for loss normalization
    overlap_mask=True,                   # overlap_mask: Merge overlapping masks into a single mask if True
    mask_ratio=4,                        # mask_ratio: Downsample ratio for segmentation masks
    dropout=0.0,                         # dropout: Dropout rate for regularization
    val=True,                            # val: Enable validation during training
    plots=True,                          # plots: Generate and save plots of training and validation metrics
    hsv_h=0.015,  # Adjusts the hue of the image by a fraction of the color wheel
    hsv_s=0.7,    # Alters the saturation for varied color intensity
    hsv_v=0.4,    # Modifies brightness to simulate different lighting conditions
    degrees=0.0,  # Rotates the image 0° (no rotation); adjust between 0 and 180 for random rotation
    translate=0.1,  # Translates the image by 10% of its size
    scale=0.5,    # Scales the image, simulating objects at different distances
    shear=0.0,    # Shears the image 0° (no shearing); modify between -180 and 180 for effect
    perspective=0.0,  # Applies no perspective transformation; use values up to 0.001 if needed
    flipud=0.0,   # Probability (0%) of flipping the image upside down
    fliplr=0.5,   # 50% chance to horizontally flip the image
    bgr=0.0,      # No conversion from RGB to BGR (0% chance)
    mosaic=1.0,   # Enables mosaic augmentation by merging four images into one
    mixup=0.0,    # Disables mixup augmentation (blends two images)
    cutmix=0.0,   # Disables cutmix augmentation (combines portions of two images)
    copy_paste=0.0,  # Disables copy-paste augmentation for segmentation
    copy_paste_mode="flip",  # Use 'flip' strategy if copy-paste is enabled
    auto_augment="randaugment",  # Applies RandAugment, a random augmentation policy for classification
    erasing=0.4    # Randomly erases regions (40% probability) to encourage robust feature extraction
)
# Out:
# Ultralytics 8.3.122 🚀 Python-3.10.17 torch-2.7.0+cu126 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 48625MiB)
#                                                         CUDA:1 (NVIDIA RTX 6000 Ada Generation, 48647MiB)
# engine/trainer: task=obb, mode=train, model=models/yolo11x-obb.pt, data=datasets/DOTAv2.0/dotav2.yml, epochs=100, time=None, patience=15, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, 1, workers=8, project=test_yolo, name=experiment_110, exist_ok=False, pretrained=False, optimizer=auto, verbose=True, seed=18, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.001, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=2.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, cutmix=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=test_yolo/experiment_110
# Overriding model.yaml nc=80 with nc=17
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   5074342  ultralytics.nn.modules.head.OBB              [17, 1, [384, 768, 768]]
# YOLO11x-obb summary: 372 layers, 58,802,566 parameters, 58,802,550 gradients, 203.9 GFLOPs
#
# Transferred 1051/1057 items from pretrained weights
# DDP: debug command /home/jupyter-dai7591/.conda/envs/yolo/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 43559 /home/jupyter-dai7591/.config/Ultralytics/DDP/_temp__w0aqktp138176406599712.py
# Ultralytics 8.3.122 🚀 Python-3.10.17 torch-2.7.0+cu126 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 48625MiB)
#                                                         CUDA:1 (NVIDIA RTX 6000 Ada Generation, 48647MiB)
# Overriding model.yaml nc=80 with nc=17
# Transferred 1051/1057 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 372MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4830.0±1859.8 MB/s, size: 598.7 KB)
# train: Scanning /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/labels/train.cache... 19361 images, 48275 backgrounds, 421 corrupt: 100%|██████████| 67636/67636 [00:00<?, ?it/s]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10084__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.093843]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10084__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.093843]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10347__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1392981]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10347__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1392981]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10347__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1392959]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10347__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1392959]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10408__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.111433]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10408__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.111433]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10408__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.111436]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10408__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.111436]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10467__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0219951]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10467__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.021994]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10550__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0381219]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10550__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.038123]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10550__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0381219]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10550__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.038123]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10773__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.104105]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10773__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.104105]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10984__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1642219]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P10984__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1642219]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P11039__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0410596]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P11039__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0410596]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3383__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0351906]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3383__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0351906]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3464__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.089448]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3464__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.089448]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3464__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.089443]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3464__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.089443]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3481__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.36364]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3481__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.36364]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3483__682__0___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1172999]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3483__682__0___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1172999]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3483__682__342___0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.117303]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3483__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.117303]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__10480___6812.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__10480___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__10480___7860.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__11004___6812.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__11004___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__11004___7860.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__18864___14148.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__18864___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__19388___14148.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__19388___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6288___17816.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6288___18340.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___11004.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___11528.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___17816.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___18340.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___4192.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___4716.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___7860.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__6812___8384.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___11004.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___11528.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___4192.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___4716.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___5764.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___7860.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7336___8384.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7860___11004.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7860___11528.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7860___4716.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7860___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__7860___5764.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___15196.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___5764.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___6288.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___6812.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8384___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___15196.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___15720.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___5764.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___6288.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___6812.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__8908___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9432___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9432___15196.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9432___1572.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9432___15720.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9432___2096.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9956___1572.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9956___2096.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9956___6812.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9956___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__1024__9956___7860.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__10480___6288.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__10480___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__17816___13624.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__17816___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__18864___13624.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__18864___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__5240___16768.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__5240___17816.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___10480.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___11528.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___16768.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___17816.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___4192.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__6288___8384.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___10480.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___11528.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___13624.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___4192.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___6288.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__7336___8384.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___1048.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___13624.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___15720.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___2096.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___4192.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___5240.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___6288.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__8384___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___1048.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___13624.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___14672.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___15720.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___2096.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___6288.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__2048__9432___7336.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10121___6980.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10121___7329.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10121___7678.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10121___8027.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10470___6980.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10470___7329.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10470___7678.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10470___8027.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10819___6980.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10819___7329.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10819___7678.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__10819___8027.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__11168___6980.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__11168___7329.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__19195___14309.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__19195___14658.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__19544___14309.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__19544___14658.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__5584___18846.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.008771]
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6282___18148.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6282___18497.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6631___18148.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6631___18497.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6980___4537.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6980___4886.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6980___5235.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6980___8027.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__6980___8376.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___11168.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___11517.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___4537.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___4886.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___5235.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___5584.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___8027.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7329___8376.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___11168.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___11517.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___4537.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___4886.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___5235.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___5584.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___5933.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__7678___8376.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8027___5235.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8027___5584.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8027___5933.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8376___5584.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8376___5933.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8376___6282.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8376___6631.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8376___6980.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8376___7329.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___15007.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___15356.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___5584.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___5933.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___6282.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___6631.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___6980.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__8725___7329.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9074___15007.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9074___15356.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9074___15705.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9074___5933.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9074___6282.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9074___6631.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# train: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/train/P3536__682__9423___15007.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# ...
# val: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/val/P9735__682__342___342.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.165689]
# val: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/val/P9997__1024__0___2620.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# val: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/val/P9997__1024__0___3072.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# val: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/val/P9997__2048__0___2048.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# val: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/val/P9997__682__0___2792.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# val: /home/jupyter-dai7591/yolo/datasets/DOTAv2.0/processed/images/val/P9997__682__0___3141.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 17. Possible class labels are 0-16
# Plotting labels to test_yolo/experiment_110/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 173 weight(decay=0.0), 183 weight(decay=0.00046875), 182 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 16 dataloader workers
# Logging results to test_yolo/experiment_110
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      16.2G      2.052      7.361      2.128          2        384:   5%|▌         | 285/5602 [00:50<15:28,  5.73it/s]W0501 15:13:24.428000 821354 site-packages/torch/distributed/elastic/agent/server/api.py:719] Received Signals.SIGINT death signal, shutting down workers
# W0501 15:13:24.430000 821354 site-packages/torch/distributed/elastic/multiprocessing/api.py:900] Sending process 821356 closing signal SIGINT
# Process Process-22:
# W0501 15:13:24.433000 821354 site-packages/torch/distributed/elastic/multiprocessing/api.py:900] Sending process 821357 closing signal SIGINT
# Traceback (most recent call last):
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#       1/100      16.2G      2.052      7.361      2.128          2        384:   5%|▌         | 286/5602 [00:51<15:49,  5.60it/s]
# [rank1]: Traceback (most recent call last):
# [rank1]:   File "/home/jupyter-dai7591/.config/Ultralytics/DDP/_temp__w0aqktp138176406599712.py", line 13, in <module>
# [rank1]:     results = trainer.train()
# [rank1]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/trainer.py", line 210, in train
# [rank1]:     self._do_train(world_size)
# [rank1]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/trainer.py", line 393, in _do_train
# [rank1]:     self.scaler.scale(self.loss).backward()
# [rank1]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/_tensor.py", line 648, in backward
# [rank1]:     torch.autograd.backward(
# [rank1]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/autograd/__init__.py", line 353, in backward
# [rank1]:     _engine_run_backward(
# [rank1]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/autograd/graph.py", line 824, in _engine_run_backward
# [rank1]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank1]: KeyboardInterrupt
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/autograd/graph.py", line 824, in _engine_run_backward
# [rank0]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank0]: KeyboardInterrupt
#
# [rank0]: During handling of the above exception, another exception occurred:
#
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/home/jupyter-dai7591/.config/Ultralytics/DDP/_temp__w0aqktp138176406599712.py", line 13, in <module>
# [rank0]:     results = trainer.train()
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/trainer.py", line 210, in train
# [rank0]:     self._do_train(world_size)
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/trainer.py", line 393, in _do_train
# [rank0]:     self.scaler.scale(self.loss).backward()
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/_tensor.py", line 648, in backward
# [rank0]:     torch.autograd.backward(
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/autograd/__init__.py", line 353, in backward
# [rank0]:     _engine_run_backward(
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/autograd/graph.py", line 824, in _engine_run_backward
# [rank0]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank0]:   File "/home/jupyter-dai7591/.conda/envs/yolo/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
# [rank0]:     _error_if_any_worker_fails()
# [rank0]: RuntimeError: DataLoader worker (pid 821426) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 results = model.train(
#       2     data="datasets/DOTAv2.0/dotav2.yml", # Path to custom dataset YAML
#       3     epochs=100,                          # Total number of training epochs
#       4     imgsz=640,                           # Input image size for training
#       5     patience=15,                         # patience: Number of epochs with no improvement before early stopping
#       6     batch=12,                            # batch: Batch size (use -1 or a fraction for auto GPU memory utilization)
#       7     save=True,                           # save: Save training checkpoints and final model weights
#       8     save_period=-1,                      # save_period: Frequency (in epochs) for saving checkpoints; -1 disables
#       9     cache=False,                         # cache: Enable caching of dataset images (True for RAM, 'disk' for disk caching)
#      10     device='0, 1',                       # device: Specify the computational device (e.g., 0, "cpu", or list of GPUs)
#      11     workers=8,                           # workers: Number of worker threads for data loading
#      12     project="test_yolo",                 # project: Name of the project directory for saving outputs
#      13     name="experiment_1",                 # name: Name of the training run
#      14     exist_ok=False,                      # exist_ok: Allow overwriting an existing project/name directory if True
#      15     pretrained=False,                    # pretrained: Start from a pretrained model or provide a path to one
#      16     optimizer="auto",                    # optimizer: Choice of optimizer (e.g., 'SGD', 'Adam', or 'auto')
#      17     seed=18,                             # seed: Random seed for reproducibility
#      18     single_cls=False,                    # single_cls: Treat all classes as a single class (useful for binary tasks)
#      19     classes=None,                        # classes: List of class IDs to train on; None uses all classes
#      20     rect=False,                          # rect: Enable rectangular training to minimize padding in batches
#      21     multi_scale=True,                    # multi_scale: Enable multi-scale training by varying the imgsz during training
#      22     cos_lr=False,                        # cos_lr: Use a cosine learning rate scheduler
#      23     close_mosaic=10,                     # close_mosaic: Disable mosaic augmentation in the last N epochs
#      24     resume=False,                        # resume: Resume training from the last checkpoint if available
#      25     amp=True,                            # amp: Enable Automatic Mixed Precision training
#      26     #fraction=1.0,                       # fraction: Fraction of the dataset to use for training
#      27     freeze=None,                         # freeze: Freeze the first N layers or specify list of layers to freeze
#      28     lr0=0.01,                            # lr0: Initial learning rate
#      29     lrf=0.001,                           # lrf: Final learning rate as a fraction of lr0 (lr0 * lrf)
#      30     momentum=0.937,                      # momentum: Momentum factor for the optimizer
#      31     weight_decay=0.0005,                 # weight_decay: L2 regularization coefficient to prevent overfitting
#      32     warmup_epochs=3.0,                   # warmup_epochs: Number of epochs for learning rate warmup
#      33     warmup_momentum=0.8,                 # warmup_momentum: Initial momentum value during the warmup phase
#      34     warmup_bias_lr=0.1,                  # warmup_bias_lr: Learning rate for bias parameters during warmup
#      35     box=7.5,                             # box: Weight of the box loss component (bounding box regression)
#      36     cls=0.5,                             # cls: Weight of the classification loss component
#      37     dfl=1.5,                             # dfl: Weight of the distribution focal loss for fine-grained classification
#      38     pose=12.0,                           # pose: Weight of the pose loss for keypoint or pose estimation tasks
#      39     kobj=2.0,                            # kobj: Weight of the keypoint objectness loss in pose estimation models
#      40     nbs=64,                              # nbs: Nominal batch size for loss normalization
#      41     overlap_mask=True,                   # overlap_mask: Merge overlapping masks into a single mask if True
#      42     mask_ratio=4,                        # mask_ratio: Downsample ratio for segmentation masks
#      43     dropout=0.0,                         # dropout: Dropout rate for regularization
#      44     val=True,                            # val: Enable validation during training
#      45     plots=True,                          # plots: Generate and save plots of training and validation metrics
#      46     hsv_h=0.015,  # Adjusts the hue of the image by a fraction of the color wheel
#      47     hsv_s=0.7,    # Alters the saturation for varied color intensity
#      48     hsv_v=0.4,    # Modifies brightness to simulate different lighting conditions
#      49     degrees=0.0,  # Rotates the image 0° (no rotation); adjust between 0 and 180 for random rotation
#      50     translate=0.1,  # Translates the image by 10% of its size
#      51     scale=0.5,    # Scales the image, simulating objects at different distances
#      52     shear=0.0,    # Shears the image 0° (no shearing); modify between -180 and 180 for effect
#      53     perspective=0.0,  # Applies no perspective transformation; use values up to 0.001 if needed
#      54     flipud=0.0,   # Probability (0%) of flipping the image upside down
#      55     fliplr=0.5,   # 50% chance to horizontally flip the image
#      56     bgr=0.0,      # No conversion from RGB to BGR (0% chance)
#      57     mosaic=1.0,   # Enables mosaic augmentation by merging four images into one
#      58     mixup=0.0,    # Disables mixup augmentation (blends two images)
#      59     cutmix=0.0,   # Disables cutmix augmentation (combines portions of two images)
#      60     copy_paste=0.0,  # Disables copy-paste augmentation for segmentation
#      61     copy_paste_mode="flip",  # Use 'flip' strategy if copy-paste is enabled
#      62     auto_augment="randaugment",  # Applies RandAugment, a random augmentation policy for classification
#      63     erasing=0.4    # Randomly erases regions (40% probability) to encourage robust feature extraction
#      64 )
#
# File ~/.conda/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/model.py:790, in Model.train(self, trainer, **kwargs)
#     787     self.model = self.trainer.model
#     789 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 790 self.trainer.train()
#     791 # Update model and cfg after training
#     792 if RANK in {-1, 0}:
#
# File ~/.conda/envs/yolo/lib/python3.10/site-packages/ultralytics/engine/trainer.py:203, in BaseTrainer.train(self)
#     201 try:
#     202     LOGGER.info(f"{colorstr('DDP:')} debug command {' '.join(cmd)}")
# --> 203     subprocess.run(cmd, check=True)
#     204 except Exception as e:
#     205     raise e
#
# File ~/.conda/envs/yolo/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/.conda/envs/yolo/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/.conda/envs/yolo/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/.conda/envs/yolo/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/.conda/envs/yolo/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %% [markdown]
# ### Validated Model

# %%
# Validate the model
model = YOLO("test_yolo/experiment_14/weights/best.pt") # n for nano, x for huge
metrics = model.val(data="dotav1.yml")  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
